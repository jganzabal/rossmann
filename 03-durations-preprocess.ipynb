# %%
import pandas as pd
import numpy as np

# %%
joined = pd.read_feather('joined_before_durations.fth')

# %% [markdown]
# ## Durations

# %% [markdown]
# ### Agrega columnas con "antes" y "despues" de eventos

# %%
columns = ["Date", "Store", "Promo", "StateHoliday", "SchoolHoliday"]

# %%
class elapsed(object):
    def __init__(self, fld):
        self.fld = fld
        self.last = pd.to_datetime(np.nan)
        self.last_store = 0
        
    def get(self, row):
        if row.Store != self.last_store:
            self.last = pd.to_datetime(np.nan)
            self.last_store = row.Store
        if (row[self.fld]): self.last = row.Date
        return row.Date-self.last

# %%
df = joined[columns]

# %%
df.head()
# Out:
#         Date  Store  Promo  StateHoliday  SchoolHoliday
# 0 2015-07-31      1      1         False              1
# 1 2015-07-31      2      1         False              1
# 2 2015-07-31      3      1         False              1
# 3 2015-07-31      4      1         False              1
# 4 2015-07-31      5      1         False              1

# %%
def add_elapsed(df, fld, prefix):
    sh_el = elapsed(fld)
    df[prefix+fld] = df.apply(sh_el.get, axis=1)

# %%
fld = 'SchoolHoliday'
df = df.sort_values(['Store', 'Date'])
add_elapsed(df, fld, 'After')
df.head()
# Out:
#               Date  Store  Promo  StateHoliday  SchoolHoliday  \
# 1016095 2013-01-01      1      0          True              1
# 1014980 2013-01-02      1      0         False              1
# 1013865 2013-01-03      1      0         False              1
# 1012750 2013-01-04      1      0         False              1
# 1011635 2013-01-05      1      0         False              1
#
#         AfterSchoolHoliday
# 1016095             0 days
# 1014980             0 days
# 1013865             0 days
# 1012750             0 days
# 1011635             0 days

# %%
df = df.sort_values(['Store', 'Date'], ascending=[True, False])
add_elapsed(df, fld, 'Before')
df.head()
# Out:
#            Date  Store  Promo  StateHoliday  SchoolHoliday AfterSchoolHoliday  \
# 0    2015-07-31      1      1         False              1             0 days
# 1115 2015-07-30      1      1         False              1             0 days
# 2230 2015-07-29      1      1         False              1             0 days
# 3345 2015-07-28      1      1         False              1             0 days
# 4460 2015-07-27      1      1         False              1             0 days
#
#      BeforeSchoolHoliday
# 0                 0 days
# 1115              0 days
# 2230              0 days
# 3345              0 days
# 4460              0 days

# %%
fld = 'StateHoliday'
df = df.sort_values(['Store', 'Date'])
add_elapsed(df, fld, 'After')
df = df.sort_values(['Store', 'Date'], ascending=[True, False])
add_elapsed(df, fld, 'Before')

# %%
fld = 'Promo'
df = df.sort_values(['Store', 'Date'])
add_elapsed(df, fld, 'After')
df = df.sort_values(['Store', 'Date'], ascending=[True, False])
add_elapsed(df, fld, 'Before')

# %%
df.head(10)
# Out:
#             Date  Store  Promo  StateHoliday  SchoolHoliday  \
# 0     2015-07-31      1      1         False              1
# 1115  2015-07-30      1      1         False              1
# 2230  2015-07-29      1      1         False              1
# 3345  2015-07-28      1      1         False              1
# 4460  2015-07-27      1      1         False              1
# 5575  2015-07-26      1      0         False              0
# 6690  2015-07-25      1      0         False              0
# 7805  2015-07-24      1      0         False              0
# 8920  2015-07-23      1      0         False              0
# 10035 2015-07-22      1      0         False              0
#
#       AfterSchoolHoliday BeforeSchoolHoliday AfterStateHoliday  \
# 0                 0 days              0 days           57 days
# 1115              0 days              0 days           56 days
# 2230              0 days              0 days           55 days
# ...

# %%
df = df.set_index("Date")

# %%
df.sort_values('Date').head(10)
# Out:
#             Store  Promo  StateHoliday  SchoolHoliday AfterSchoolHoliday  \
# Date
# 2013-01-01   1115      0          True              1             0 days
# 2013-01-01    746      0          True              1             0 days
# 2013-01-01    171      0          True              1             0 days
# 2013-01-01    694      0          True              1             0 days
# 2013-01-01    396      0          True              1             0 days
# 2013-01-01    196      0          True              1             0 days
# 2013-01-01    271      0          True              1             0 days
# 2013-01-01     32      0          True              1             0 days
# 2013-01-01    440      0          True              1             0 days
# 2013-01-01   1090      0          True              1             0 days
#
#            BeforeSchoolHoliday AfterStateHoliday BeforeStateHoliday  \
# Date
# 2013-01-01              0 days            0 days             0 days
# ...

# %% [markdown]
# NaT: Not a Time

# %% [markdown]
# ### Elimina los NaT

# %%
columns = ['SchoolHoliday', 'StateHoliday', 'Promo']

# %%
for o in ['Before', 'After']:
    for p in columns:
        a = o+p
        df[a] = df[a].fillna(pd.Timedelta(0)).dt.days

# %%
df.sort_values('Date').head(10)
# Out:
#             Store  Promo  StateHoliday  SchoolHoliday  AfterSchoolHoliday  \
# Date
# 2013-01-01   1115      0          True              1                   0
# 2013-01-01    746      0          True              1                   0
# 2013-01-01    171      0          True              1                   0
# 2013-01-01    694      0          True              1                   0
# 2013-01-01    396      0          True              1                   0
# 2013-01-01    196      0          True              1                   0
# 2013-01-01    271      0          True              1                   0
# 2013-01-01     32      0          True              1                   0
# 2013-01-01    440      0          True              1                   0
# 2013-01-01   1090      0          True              1                   0
#
#             BeforeSchoolHoliday  AfterStateHoliday  BeforeStateHoliday  \
# Date
# ...

# %% [markdown]
# ### "Suavizado" de columnas temporales

# %%
df[df[['Store']+columns]['Store'] == 1].sort_values('Date').head(20)
# Out:
#             Store  Promo  StateHoliday  SchoolHoliday  AfterSchoolHoliday  \
# Date
# 2013-01-01      1      0          True              1                   0
# 2013-01-02      1      0         False              1                   0
# 2013-01-03      1      0         False              1                   0
# 2013-01-04      1      0         False              1                   0
# 2013-01-05      1      0         False              1                   0
# 2013-01-06      1      0         False              1                   0
# 2013-01-07      1      1         False              1                   0
# 2013-01-08      1      1         False              1                   0
# 2013-01-09      1      1         False              1                   0
# 2013-01-10      1      1         False              1                   0
# 2013-01-11      1      1         False              1                   0
# 2013-01-12      1      0         False              0                   1
# ...

# %%
bwd = df[['Store']+columns].sort_index().groupby("Store").rolling(7, min_periods=1).sum()
bwd.head(20)
# Out:
#                   Store  SchoolHoliday  StateHoliday  Promo
# Store Date
# 1     2013-01-01    1.0            1.0           1.0    0.0
#       2013-01-02    2.0            2.0           1.0    0.0
#       2013-01-03    3.0            3.0           1.0    0.0
#       2013-01-04    4.0            4.0           1.0    0.0
#       2013-01-05    5.0            5.0           1.0    0.0
#       2013-01-06    6.0            6.0           1.0    0.0
#       2013-01-07    7.0            7.0           1.0    1.0
#       2013-01-08    7.0            7.0           0.0    2.0
#       2013-01-09    7.0            7.0           0.0    3.0
#       2013-01-10    7.0            7.0           0.0    4.0
#       2013-01-11    7.0            7.0           0.0    5.0
#       2013-01-12    7.0            6.0           0.0    5.0
#       2013-01-13    7.0            5.0           0.0    5.0
#       2013-01-14    7.0            4.0           0.0    4.0
# ...

# %%
bwd.drop('Store',1,inplace=True)
bwd.reset_index(inplace=True)

# %%
bwd.head(20)
# Out:
#     Store       Date  SchoolHoliday  StateHoliday  Promo
# 0       1 2013-01-01            1.0           1.0    0.0
# 1       1 2013-01-02            2.0           1.0    0.0
# 2       1 2013-01-03            3.0           1.0    0.0
# 3       1 2013-01-04            4.0           1.0    0.0
# 4       1 2013-01-05            5.0           1.0    0.0
# 5       1 2013-01-06            6.0           1.0    0.0
# 6       1 2013-01-07            7.0           1.0    1.0
# 7       1 2013-01-08            7.0           0.0    2.0
# 8       1 2013-01-09            7.0           0.0    3.0
# 9       1 2013-01-10            7.0           0.0    4.0
# 10      1 2013-01-11            7.0           0.0    5.0
# 11      1 2013-01-12            6.0           0.0    5.0
# 12      1 2013-01-13            5.0           0.0    5.0
# 13      1 2013-01-14            4.0           0.0    4.0
# 14      1 2013-01-15            3.0           0.0    3.0
# ...

# %%
# Ordena al reves
fwd = df[['Store']+columns].sort_index(ascending=False).groupby("Store").rolling(7, min_periods=1).sum()

# %%
fwd.head(20)
# Out:
#                   Store  SchoolHoliday  StateHoliday  Promo
# Store Date
# 1     2015-07-31    1.0            1.0           0.0    1.0
#       2015-07-30    2.0            2.0           0.0    2.0
#       2015-07-29    3.0            3.0           0.0    3.0
#       2015-07-28    4.0            4.0           0.0    4.0
#       2015-07-27    5.0            5.0           0.0    5.0
#       2015-07-26    6.0            5.0           0.0    5.0
#       2015-07-25    7.0            5.0           0.0    5.0
#       2015-07-24    7.0            4.0           0.0    4.0
#       2015-07-23    7.0            3.0           0.0    3.0
#       2015-07-22    7.0            2.0           0.0    2.0
#       2015-07-21    7.0            1.0           0.0    1.0
#       2015-07-20    7.0            0.0           0.0    0.0
#       2015-07-19    7.0            0.0           0.0    0.0
#       2015-07-18    7.0            0.0           0.0    0.0
# ...

# %%
fwd.drop('Store',1,inplace=True)
fwd.reset_index(inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df = df.merge(bwd, 'left', ['Date', 'Store'], suffixes=['', '_bw'])
df = df.merge(fwd, 'left', ['Date', 'Store'], suffixes=['', '_fw'])

# %%
df.drop(columns,1,inplace=True)

# %%
df.head()
# Out:
#         Date  Store  AfterSchoolHoliday  BeforeSchoolHoliday  \
# 0 2015-07-31      1                   0                    0
# 1 2015-07-30      1                   0                    0
# 2 2015-07-29      1                   0                    0
# 3 2015-07-28      1                   0                    0
# 4 2015-07-27      1                   0                    0
#
#    AfterStateHoliday  BeforeStateHoliday  AfterPromo  BeforePromo  \
# 0                 57                   0           0            0
# 1                 56                   0           0            0
# 2                 55                   0           0            0
# 3                 54                   0           0            0
# 4                 53                   0           0            0
#
#    SchoolHoliday_bw  StateHoliday_bw  Promo_bw  SchoolHoliday_fw  \
# 0               5.0              0.0       5.0               1.0
# 1               4.0              0.0       4.0               2.0
# ...

# %%
df["Date"] = pd.to_datetime(df.Date)

# %%
df.head()
# Out:
#         Date  Store  AfterSchoolHoliday  BeforeSchoolHoliday  \
# 0 2015-07-31      1                   0                    0
# 1 2015-07-30      1                   0                    0
# 2 2015-07-29      1                   0                    0
# 3 2015-07-28      1                   0                    0
# 4 2015-07-27      1                   0                    0
#
#    AfterStateHoliday  BeforeStateHoliday  AfterPromo  BeforePromo  \
# 0                 57                   0           0            0
# 1                 56                   0           0            0
# 2                 55                   0           0            0
# 3                 54                   0           0            0
# 4                 53                   0           0            0
#
#    SchoolHoliday_bw  StateHoliday_bw  Promo_bw  SchoolHoliday_fw  \
# 0               5.0              0.0       5.0               1.0
# 1               4.0              0.0       4.0               2.0
# ...

# %%
def join_df(left, right, left_on, right_on=None):
    if right_on is None: right_on = left_on
    return left.merge(right, how='left', left_on=left_on, right_on=right_on, 
                      suffixes=("", "_y"))

# %%
joined = join_df(joined, df, ['Store', 'Date'])

# %%
joined.shape
# Out:
# (1017209, 80)

# %%
joined.to_feather('all_preprocessed.fth')
